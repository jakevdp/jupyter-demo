# %% [markdown]
# # Star-Galaxy Exploration

# %%
# %matplotlib inline
import seaborn as sns
# Out:
# /Users/jakevdp/anaconda/envs/python3.5/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from star_galaxy.data import get_star_galaxy_data

df = get_star_galaxy_data()
# Out:
# /Users/jakevdp/anaconda/envs/python3.5/lib/python3.5/site-packages/astroquery/sdss/__init__.py:28: UserWarning: Experimental: SDSS has not yet been refactored to have its API match the rest of astroquery (but it's nearly there).
#   warnings.warn("Experimental: SDSS has not yet been refactored to have its API "

# %%
df.head()
# Out:
#    psfMag_r  fiberMag_r  fiber2Mag_r  petroMag_r  deVMag_r  expMag_r  \
# 0  18.50319    18.65275     19.33509    17.54539  17.31526  17.58132
# 1  19.02659    19.32441     19.80892    19.05827  19.03468  19.03111
# 2  19.88090    19.77895     20.46623    19.35340  19.18640  19.35493
# 3  22.03563    22.06141     22.68416    21.51795  21.03554  21.31751
# 4  21.56726    21.57312     22.22178    20.45830  19.93309  20.39825
#
#    modelMag_r  cModelMag_r      class
# 0    17.58132     17.48715  b'GALAXY'
# 1    19.03111     19.03111    b'STAR'
# 2    19.35493     19.24559  b'GALAXY'
# 3    21.31751     21.31751  b'GALAXY'
# 4    20.39819     20.20402  b'GALAXY'

# %%
sns.pairplot(df, hue='class');
# Out:
# /Users/jakevdp/anaconda/envs/python3.5/lib/python3.5/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
